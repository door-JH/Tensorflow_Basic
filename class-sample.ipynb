# %%
# import tensorflow as tf
# import keras
# print(tf.__version__)
# print(keras.__version__)
# !python --version

# %%
#google drive 연동

# import os
# from google.colab import drive
# drive.mount("/content/gdrive")
# os.chdir("/content/gdrive/My Drive/class-sample")
# !ls -lia;pwd

# %%
# Out:
# 200
